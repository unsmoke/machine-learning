# %%
import pandas as pd
import pyreadstat

# Ganti 'path_to_file' dengan path aktual file .sav Anda
df, meta = pyreadstat.read_sav('./data/d8d9b746-3fe4-4077-a4f3-552154c16699/researchdata/Stop-tabac Yareta data 2022 05 19.sav')

# Menampilkan beberapa baris pertama dari DataFrame
df.head()
# Out:
#    date_courante eligible  touslesjours  moisfum  yearfum   age  utiliseapp  \
# 0   2.019041e+11        Y           1.0      1.0   1997.0  37.0         1.0
# 1   2.019041e+11        Y           1.0      7.0   1997.0  41.0         1.0
# 2   2.019041e+11        Y           1.0      1.0   2012.0  25.0         1.0
# 3   2.019041e+11        Y           1.0      1.0   2004.0  31.0         1.0
# 4   2.019041e+11        Y           1.0      2.0   1995.0  60.0         1.0
#
#    datearret30  arretserieux  usestoptabac  ...  Minutes_cat  yrmdatequit7d  \
# 0   20190415.0           1.0           2.0  ...          1.0       159430.0
# 1   20190410.0           1.0           2.0  ...          4.0            NaN
# 2   20190410.0           1.0           2.0  ...          2.0            NaN
# 3   20190410.0           1.0           2.0  ...          4.0            NaN
# 4   20190413.0           1.0           2.0  ...          4.0            NaN
#
# ...

# %%
data = pd.read_csv('data.csv')

data.head()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_11272\214872866.py:1: DtypeWarning: Columns (35,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('data.csv')
#    Current Date Eligible  Every Day  Smoking Month  Smoking Year   Age  \
# 0  2.019041e+11        Y        1.0            1.0        1997.0  37.0
# 1  2.019041e+11        Y        1.0            7.0        1997.0  41.0
# 2  2.019041e+11        Y        1.0            1.0        2012.0  25.0
# 3  2.019041e+11        Y        1.0            1.0        2004.0  31.0
# 4  2.019041e+11        Y        1.0            2.0        1995.0  60.0
#
#    Uses App  Stop Date 30  Serious Quit Attempt  Uses StopTabac  ...  \
# 0       1.0    20190415.0                   1.0             2.0  ...
# 1       1.0    20190410.0                   1.0             2.0  ...
# 2       1.0    20190410.0                   1.0             2.0  ...
# ...

# %%
len(data.columns.to_list())
# Out:
# 148

# %%
data.columns.to_list()
# Out:
# ['Current Date',
#  'Eligible',
#  'Every Day',
#  'Smoking Month',
#  'Smoking Year',
#  'Age',
#  'Uses App',
#  'Stop Date 30',
#  'Serious Quit Attempt',
#  'Uses StopTabac',
#  'Engagement Response',
#  'Gender',
#  'Country',
#  'Looks at Email',
#  'Cigarettes Per Day',
#  'Minutes',
#  'Smokes Other',
#  'Heated Cigarette Use',
#  'Electronic Cigarette Use',
#  'Uses Substitutes',
#  'Depressed',
#  'No Pleasure',
#  'Group',
#  'Current Date 7d',
#  'Smoked Last 7 Days',
#  'Used Heated Tobacco 7d',
#  'Used E-Cig 7d',
#  'Used Substitutes 7d',
#  'Used Other App 7d',
#  'Other App1 7d',
#  'Other App2 7d',
#  'Other App3 7d',
#  'Smoked After 7d',
#  'App Helps Quitting 7d',
#  'Useful Elements 7d',
#  'Smoking Day 7d',
#  'Smoking Month 7d',
#  'Smoking Year 7d',
#  'Cigarettes Per Day 7d',
#  'Serious Quit Attempt 7d',
#  'Intention to Quit 7d',
#  'Type of Response 7d',
#  'Current Date 1m',
#  'Smoked Last 7 Days 1m',
#  'Smoked Last 4 Weeks 1m',
# ...

# %%
len(data['Interval Target Quit Date to Quit Day 1 Month'].isnull())
# Out:
# 5293
